# %% [markdown]
# <a href="https://colab.research.google.com/github/mp7586093-del/programacion-de-computadores/blob/main/notebook1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CONTENIDOS
# 1. introduccion
# 2. objetivos
# 3. metodologia
# 4. analisis
# 5. ecuaciones

# %% [markdown]
# # INTRODUCCION
# hjjacbnuvfajsdcbhfbvsijdclasvjnrhvcjasNCJSABVOhc{DSCNJFBVUSDHFV{ONDFVNVAJDFVJASDFOV

# %% [markdown]
# # OBJETIVOS
# bvsdbfvseubrjvasdbvjabñobvkjabcxnbvavu

# %% [markdown]
# ## OBJETIVO GENERAL
# lajsbvfjasbvhabslufhajnsbvjlsuhñfbasbdfcnsdbcabcñasnababcnasbabrvabvnabxdndasjbfawenasdbcvabv

# %% [markdown]
# ## OBJETIVOS ESPECIFICOS
# + primer objetivo
# + segundo objetivo
# + tercer objetivo

# %% [markdown]
# # ECUACIONES
# 1. ecuacion de la energia: $e=m*c^2$
# todas las ecuaciones en formato latex se encuentran en el siguiente link
#
# [apuntes de latex]https://metodos.fam.cie.uva.es/~latex/apuntes/apuntes3.pdf
